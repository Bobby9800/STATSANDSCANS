# %% [markdown]
# <a href="https://colab.research.google.com/github/Bobby9800/STATSANDSCANS/blob/main/DfSummarytools.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install summarytools
# Out:
# ...
#   Using cached jedi-0.19.1-py2.py3-none-any.whl.metadata (22 kB)
# ...
# Using cached jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
# ...

# %%
import pandas as pd
from summarytools import dfSummary
df=pd.read_csv('Netflix Userbase.csv')
df.head(2)
# Out:
#    User ID Subscription Type  Monthly Revenue Join Date  ... Age  Gender      Device Plan Duration
# 0        1             Basic               10  15-01-22  ...  28    Male  Smartphone       1 Month
# 1        2           Premium               15  05-09-21  ...  35  Female      Tablet       1 Month
#
# [2 rows x 10 columns]

# %%
dfSummary(df)
# Out:
# <style type="text/css">
# #T_14442 thead>tr>th {
#   text-align: left;
# }
# #T_14442_row0_col0, #T_14442_row1_col0, #T_14442_row2_col0, #T_14442_row3_col0, #T_14442_row4_col0, #T_14442_row5_col0, #T_14442_row6_col0, #T_14442_row7_col0, #T_14442_row8_col0, #T_14442_row9_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_14442_row0_col1, #T_14442_row1_col1, #T_14442_row2_col1, #T_14442_row3_col1, #T_14442_row4_col1, #T_14442_row5_col1, #T_14442_row6_col1, #T_14442_row7_col1, #T_14442_row8_col1, #T_14442_row9_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_14442_row0_col2, #T_14442_row1_col2, #T_14442_row2_col2, #T_14442_row3_col2, #T_14442_row4_col2, #T_14442_row5_col2, #T_14442_row6_col2, #T_14442_row7_col2, #T_14442_row8_col2, #T_14442_row9_col2 {
# ...
